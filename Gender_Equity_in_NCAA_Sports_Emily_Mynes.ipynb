# %% [markdown]
# <a href="https://colab.research.google.com/github/emily-mynes/DSRP_Gender_Equity_In_NCAA-Emily-Mynes/blob/main/Gender_Equity_in_NCAA_Sports_Emily_Mynes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score

# %%
url = "https://raw.githubusercontent.com/frontiertechinstitute/datasets/refs/heads/main/ncaa_cleaned.csv"
df = pd.read_csv(url)

# %%
df['sector_name'][17336: 17345] = 'Public, 4-year or above'
df['sector_name'][34750: 34759] = 'Public, 4-year or above'
df['sector_name'][52378: 52387] = 'Public, 4-year or above'
df['sector_name'][70150: 70159] = 'Public, 4-year or above'
df['sector_name'][132318: 132327] = 'Public, 4-year or above'
df[df['sector_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [year, institution_name, city_txt, state_cd, classification_code, classification_name, ef_male_count, ef_female_count, ef_total_count, sector_name, partic_men, partic_women, sum_partic_men, sum_partic_women, rev_men, rev_women, total_rev_menwomen, exp_men, exp_women, total_exp_menwomen, sports]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['state_cd'][17336: 17345] = 'None'
df['state_cd'][34750: 34759] = 'None'
df['state_cd'][52378: 52387] = 'None'
df['state_cd'][70150: 70159] = 'None'
df['state_cd'][132318: 132327] = 'None'

# %%
df['city_txt'][17336: 17345] = 'None'
df['city_txt'][34750: 34759] = 'None'
df['city_txt'][52378: 52387] = 'None'
df['city_txt'][70150: 70159] = 'None'
df['city_txt'][132318: 132327] = 'None'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132327 entries, 0 to 132326
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 132327 non-null  int64
#  1   institution_name     132327 non-null  object
#  2   city_txt             132327 non-null  object
#  3   state_cd             132327 non-null  object
#  4   classification_code  132327 non-null  int64
#  5   classification_name  132327 non-null  object
#  6   ef_male_count        132327 non-null  int64
#  7   ef_female_count      132327 non-null  int64
#  8   ef_total_count       132327 non-null  int64
#  9   sector_name          132327 non-null  object
#  10  partic_men           61865 non-null   float64
#  11  partic_women         68885 non-null   float64
#  12  sum_partic_men       132327 non-null  int64
#  13  sum_partic_women     132327 non-null  int64
#  14  rev_men              61865 non-null   float64
# ...

# %%
for i in range(len(df)):
  if df['partic_men'][i] == 'NaN' and df['sum_partic_men'] == 0:
    df['partic_men'][i] = 0
df[df['partic_men'].isnull()]
# Out:
#         year                     institution_name    city_txt state_cd  \
# 5       2015             Alabama A & M University      Normal       AL
# 6       2015             Alabama A & M University      Normal       AL
# 8       2015             Alabama A & M University      Normal       AL
# 9       2015             Alabama A & M University      Normal       AL
# 12      2015  University of Alabama at Birmingham  Birmingham       AL
# ...      ...                                  ...         ...      ...
# 132313  2019          Purdue University Northwest     Hammond       IN
# 132314  2019          Purdue University Northwest     Hammond       IN
# 132315  2019          Purdue University Northwest     Hammond       IN
# 132323  2019              Simon Fraser University         NaN      NaN
# 132325  2019              Simon Fraser University         NaN      NaN
#
#         classification_code                classification_name  ef_male_count  \
# ...

# %%
# Out:
# np.float64(nan)
